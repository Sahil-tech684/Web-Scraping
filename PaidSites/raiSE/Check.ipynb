# %%
import pandas as pd

df = pd.read_csv('raiSeData.csv')
df
# Out:
#                                   Name               Name of Business  \
# 0              10:10 Media Productions  Creative, Media & Publication
# 1                                Aison          Professional Services
# 2                          Hush TeaBar           Education & Training
# 3    All Hearts Adventure And Training           Education & Training
# 4               Amazing Speech Therapy       Health & Social Services
# ..                                 ...                            ...
# 260    Yoon's Traditional Teochew Kueh                Food & Beverage
# 261                             XIOHOO                       Training
# 262          World Toilet Organization       Health & Social Services
# 263                        WILL & WELL               Fashion & Retail
# 264    We Create Opportunities For All          Professional Services
#
#                                         Area of Impact  \
# 0                Provision of employment opportunities
# ...
