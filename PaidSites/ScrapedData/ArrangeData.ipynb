# %%
import pandas as pd

df = pd.read_csv('Pillar_CleanedData.csv')
df
# Out:
#                                                   Name  \
# 0          Big Brothers Big Sisters of London and Area
# 1                                                  NaN
# 2                                           BGC London
# 3    Architectural Conservancy Ontario - London Region
# 4                      Atlohsa Family Healing Services
# ..                                                 ...
# 216                       YMCA of Southwestern Ontario
# 217                          WILL Employment Solutions
# 218                                   Young Associates
# 219                                      Theatre Aezir
# 220                         The Urban League of London
#
#                                                   Decp  \
# 0    Big Brothers Big Sisters is a volunteer-driven...
# 1                                                  NaN
# 2    BGC London (Boys & Girls Club of London) is a ...
# 3                                                  NaN
# ...
