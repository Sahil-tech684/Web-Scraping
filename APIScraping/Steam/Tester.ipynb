# %%
import pandas as pd

df = pd.read_csv('Steam_reviews.csv')
df
# Out:
#                           Date  \
# 0    Posted: February 26, 2022
# 1       Posted: August 1, 2019
# 2        Posted: March 2, 2021
# 3        Posted: July 27, 2021
# 4              Posted: June 13
# ..                         ...
# 497        Posted: November 12
# 498        Posted: November 11
# 499        Posted: November 11
# 500        Posted: November 11
# 501        Posted: November 11
#
#                                               Reaction  \
# 0    \r\n\t\t\t\t993 people found this review helpf...
# 1    \r\n\t\t\t\t659 people found this review helpf...
# 2    \r\n\t\t\t\t941 people found this review helpf...
# 3    \r\n\t\t\t\t691 people found this review helpf...
# 4    \r\n\t\t\t\t2,620 people found this review hel...
# ..                                                 ...
# 497  \r\n\t\t\t\t1 person found this review helpful...
# 498  \r\n\t\t\t\t1 person found this review helpful...
# 499  \r\n\t\t\t\t1 person found this review helpful...
# ...

# %%
df['Reaction'] = df['Reaction'].str.strip()
df['Review'] = df['Review'].str.strip()
df
# Out:
#                           Date  \
# 0    Posted: February 26, 2022
# 1       Posted: August 1, 2019
# 2        Posted: March 2, 2021
# 3        Posted: July 27, 2021
# 4              Posted: June 13
# ..                         ...
# 497        Posted: November 12
# 498        Posted: November 11
# 499        Posted: November 11
# 500        Posted: November 11
# 501        Posted: November 11
#
#                                               Reaction  \
# 0    993 people found this review helpful,864 peopl...
# 1    659 people found this review helpful,210 peopl...
# 2    941 people found this review helpful,474 peopl...
# 3    691 people found this review helpful,410 peopl...
# 4    2,620 people found this review helpful,72 peop...
# ..                                                 ...
# 497       1 person found this review helpful\t\t\t\t,0
# 498       1 person found this review helpful\t\t\t\t,0
# 499       1 person found this review helpful\t\t\t\t,0
# ...

# %%
df.to_csv('Steam_GTA_V.csv',index=False)
